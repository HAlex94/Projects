# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.4)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('bruton tyrosine kinase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references           organism  \
# 0     [{'xref_id': 'Q06187', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                    []       Mus musculus
# 2                                                    []       Homo sapiens
# 3                                                    []       Homo sapiens
# 4                                                    []       Homo sapiens
# ...                                                 ...                ...
# 1527                                                 []       Homo sapiens
# 1528                                                 []       Homo sapiens
# 1529                                                 []  Rattus norvegicus
# 1530                                                 []       Homo sapiens
# 1531                                                 []       Homo sapiens
#
#                                               pref_name  score  \
# 0                           Tyrosine-protein kinase BTK   28.0
# 1                           Tyrosine-protein kinase BTK   28.0
# 2          Protein cereblon/Tyrosine-protein kinase BTK   27.0
# 3                       VHL/Tyrosine-protein kinase BTK   25.0
# 4                                     TEC family kinase   21.0
# ...                                                 ...    ...
# 1527  Heat shock protein HSP 90-beta/Hsp90 co-chaper...    2.0
# 1528                               mTOR/FKBP12A/FKBP12B    2.0
# 1529                           TGF-beta receptor type-1    2.0
# 1530          RNA cytosine C(5)-methyltransferase NSUN2    2.0
# 1531         VHL/Protein arginine N-methyltransferase 5    2.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL5251
# 1                  False    CHEMBL3259478
# 2                  False    CHEMBL4523704
# 3                  False    CHEMBL4630740
# 4                  False    CHEMBL4296642
# ...                  ...              ...
# 1527               False    CHEMBL4296081
# 1528               False    CHEMBL4296662
# 1529               False    CHEMBL4523265
# 1530               False    CHEMBL4739683
# 1531               False    CHEMBL4748215
#
#                                       target_components  \
# 0     [{'accession': 'Q06187', 'component_descriptio...
# 1     [{'accession': 'P35991', 'component_descriptio...
# 2     [{'accession': 'Q06187', 'component_descriptio...
# 3     [{'accession': 'Q06187', 'component_descriptio...
# 4     [{'accession': 'Q08881', 'component_descriptio...
# ...                                                 ...
# 1527  [{'accession': 'P08238', 'component_descriptio...
# 1528  [{'accession': 'P62942', 'component_descriptio...
# 1529  [{'accession': 'P80204', 'component_descriptio...
# 1530  [{'accession': 'Q08J23', 'component_descriptio...
# 1531  [{'accession': 'O14744', 'component_descriptio...
#
#                       target_type  tax_id
# 0                  SINGLE PROTEIN    9606
# 1                  SINGLE PROTEIN   10090
# 2     PROTEIN-PROTEIN INTERACTION    9606
# 3     PROTEIN-PROTEIN INTERACTION    9606
# 4                  PROTEIN FAMILY    9606
# ...                           ...     ...
# 1527              PROTEIN COMPLEX    9606
# 1528              PROTEIN COMPLEX    9606
# 1529               SINGLE PROTEIN   10116
# 1530               SINGLE PROTEIN    9606
# 1531  PROTEIN-PROTEIN INTERACTION    9606
#
# [1532 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Bruton Tyrosine Kinase***

# %% [markdown]
# We will assign the first  entry (which corresponds to the target protein, *Bruton Tyrosine Kinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL5251'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Bruton Tyronsine Kinase* (CHEMBL5251) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1173948                  []
# 1        None             None      1712362                  []
# 2        None             None      1713430                  []
#
#   assay_chembl_id                      assay_description assay_type  \
# 0    CHEMBL648220  Inhibition of Brutons tyrosine kinase          B
# 1    CHEMBL861964                      Inhibition of BTK          B
# 2    CHEMBL861964                      Inhibition of BTK          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
#   target_organism             target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Tyrosine-protein kinase BTK          9606       None  None
# 1    Homo sapiens  Tyrosine-protein kinase BTK          9606       None  None
# 2    Homo sapiens  Tyrosine-protein kinase BTK          9606       None  None
#
#    type units    uo_units upper_value   value
# 0  IC50    uM  UO_0000065        None  0.0004
# 1  IC50    uM  UO_0000065        None    15.1
# 2  IC50    uM  UO_0000065        None     4.1
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 4521948 Aug 13 20:52 '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1173948,[],CHEMBL648220,Inhibition of Brutons tyrosine kinase,B,,,BAO_0000190,BAO_0000357,single protein format,CCN(CC)C/C=C/c1nc(O)c2c(ccc3nc(Nc4c(Cl)cccc4Cl)n(C)c32)c1C,,,CHEMBL1136753,J Med Chem,2003.0,"{'bei': '19.40', 'le': '0.39', 'lle': '2.86', 'sei': '14.19'}",CHEMBL281957,,CHEMBL281957,9.40,0,http://www.openphacts.org/units/Nanomolar,39786,=,1,1,=,,IC50,nM,,0.4,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,0.0004
# ,,1712362,[],CHEMBL861964,Inhibition of BTK,B,,,BAO_0000190,BAO_0000357,single protein format,NC(=O)c1sc(-c2ccccc2)cc1N,,,CHEMBL1147674,J Med Chem,2006.0,"{'bei': '22.09', 'le': '0.44', 'lle': '2.72', 'sei': '6.98'}",CHEMBL207028,,CHEMBL207028,4.82,0,http://www.openphacts.org/units/Nanomolar,471397,=,1,1,=,,IC50,nM,,15100.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,15.1
# ,,1713430,[],CHEMBL861964,Inhibition of BTK,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cc(C)c2c(N)c(C(N)=O)sc2n1,,,CHEMBL1147674,J Med Chem,2006.0,"{'bei': '24.35', 'le': '0.49', 'lle': '3.80', 'sei': '6.57'}",CHEMBL377085,,CHEMBL377085,5.39,0,http://www.openphacts.org/units/Nanomolar,471432,=,1,1,=,,IC50,nM,,4100.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,4.1
# ,,1734751,[],CHEMBL865400,Inhibition of Btk,B,,,BAO_0000190,BAO_0000357,single protein format,COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)cc3)s2)cc1C(=O)N1CCN(C(C)=O)CC1,,,CHEMBL1138957,Bioorg Med Chem Lett,2006.0,"{'bei': '8.64', 'le': '0.17', 'lle': '-0.30', 'sei': '5.19'}",CHEMBL209148,,CHEMBL209148,5.39,0,http://www.openphacts.org/units/Nanomolar,523262,=,1,1,=,,IC50,nM,,4100.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,4.1
# ,,1748681,[],CHEMBL870355,Inhibition of Btk,B,,,BAO_0000190,BAO_0000357,single protein format,COc1ccc(N(C(=O)Oc2c(C)cccc2C)c2ccnc(Nc3cc(OC)c(OCCCN4CCN(C)CC4)c(OC)c3)n2)c(OC)c1,,,CHEMBL1145338,J Med Chem,2006.0,"{'bei': '10.19', 'le': '0.19', 'lle': '0.78', 'sei': '5.83'}",CHEMBL386760,,CHEMBL386760,7.00,0,http://www.openphacts.org/units/Nanomolar,533350,=,1,1,=,,IC50,nM,,100.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,0.1
# ,,1765468,[],CHEMBL853494,Inhibition of Btk by HTRF kinase assay,B,,,BAO_0000190,BAO_0000357,single protein format,CNc1ncc2cc(-c3cc(C(=O)Nc4cc(C(F)(F)F)ccc4OC4CCN(C)CC4)ccc3C)ccc2n1,,,CHEMBL1149344,J Med Chem,2006.0,"{'bei': '9.97', 'le': '0.19', 'lle': '-0.91', 'sei': '6.90'}",CHEMBL386661,,CHEMBL386661,5.48,0,http://www.openphacts.org/units/Nanomolar,565637,=,1,1,=,,IC50,nM,,3330.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,3.33
# ,,1765497,[],CHEMBL853494,Inhibition of Btk by HTRF kinase assay,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1ccc(C(=O)Nc2cccc(C(F)(F)F)c2)cc1-c1ccc2nc(NCCN3CCOCC3)ncc2c1,,,CHEMBL1149344,J Med Chem,2006.0,"{'bei': '11.70', 'le': '0.22', 'lle': '0.64', 'sei': '7.89'}",CHEMBL215943,,CHEMBL215943,6.26,0,http://www.openphacts.org/units/Nanomolar,565656,=,1,1,=,,IC50,nM,,545.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,0.545
# ,,1815214,[],CHEMBL908525,Inhibition of BTK,B,,,BAO_0000190,BAO_0000357,single protein format,CNc1ncnc(-c2cccnc2Oc2ccc(F)c(C(=O)Nc3cc(C(F)(F)F)ccc3N(C)CCCN(C)C)c2)n1,,,CHEMBL1141380,J Med Chem,2007.0,"{'bei': '7.69', 'le': '0.15', 'lle': '-0.97', 'sei': '4.25'}",CHEMBL373882,,CHEMBL373882,4.60,0,http://www.openphacts.org/units/Nanomolar,624639,=,1,1,=,,IC50,nM,,25000.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,nM,UO_0000065,,25000.0
# ,,1923433,[],CHEMBL896207,Inhibition of BTK,B,,,BAO_0000190,BAO_0000357,single protein format,Cn1cnc(CNc2cc(Br)c3ncc(C#N)c(Nc4ccc(F)c(Cl)c4)c3c2)c1,,,CHEMBL1148782,J Med Chem,2007.0,,CHEMBL230761,,CHEMBL230761,,0,http://www.openphacts.org/units/Nanomolar,655129,>,1,1,>,,IC50,nM,,10000.0,CHEMBL5251,Homo sapiens,Tyrosine-protein kinase BTK,9606,,,IC50,uM,UO_0000065,,10.0

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4707  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4708  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4709  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4710  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4711                                               None             None
#
#       activity_id                                activity_properties  \
# 0         1173948                                                 []
# 1         1712362                                                 []
# 2         1713430                                                 []
# 3         1734751                                                 []
# 4         1748681                                                 []
# ...           ...                                                ...
# 4707     24953771  [{'comments': None, 'relation': None, 'result_...
# 4708     24953974  [{'comments': None, 'relation': None, 'result_...
# 4709     24954226  [{'comments': None, 'relation': None, 'result_...
# 4710     24954234  [{'comments': None, 'relation': None, 'result_...
# 4711     24957961  [{'comments': None, 'relation': None, 'result_...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL648220              Inhibition of Brutons tyrosine kinase
# 1       CHEMBL861964                                  Inhibition of BTK
# 2       CHEMBL861964                                  Inhibition of BTK
# 3       CHEMBL865400                                  Inhibition of Btk
# 4       CHEMBL870355                                  Inhibition of Btk
# ...              ...                                                ...
# 4707   CHEMBL5209939  Affinity Phenotypic Cellular interaction (Cell...
# 4708   CHEMBL5210135  Affinity On-target Cellular interaction (HTRF-...
# 4709   CHEMBL5210344  Affinity Biochemical interaction (IMAP (immobi...
# 4710   CHEMBL5210354  Affinity Biochemical interaction (33P-ATP and ...
# 4711   CHEMBL5212883  Selectivity interaction (Enzymatic assay) EUB0...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4707          F                    None                   None  BAO_0000190
# 4708          B                    None                   None  BAO_0000190
# 4709          B                    None                   None  BAO_0000190
# 4710          B                    None                   None  BAO_0000190
# 4711          B                    None                   None  BAO_0000190
#
#       ... target_organism             target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 1     ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 2     ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 3     ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 4     ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# ...   ...             ...                          ...           ...
# 4707  ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 4708  ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 4709  ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 4710  ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
# 4711  ...    Homo sapiens  Tyrosine-protein kinase BTK          9606
#
#      text_value  toid  type units    uo_units upper_value   value
# 0          None  None  IC50    uM  UO_0000065        None  0.0004
# 1          None  None  IC50    uM  UO_0000065        None    15.1
# 2          None  None  IC50    uM  UO_0000065        None     4.1
# 3          None  None  IC50    uM  UO_0000065        None     4.1
# 4          None  None  IC50    uM  UO_0000065        None     0.1
# ...         ...   ...   ...   ...         ...         ...     ...
# 4707       None  None  IC50    nM  UO_0000065        None   360.0
# 4708       None  None  IC50    nM  UO_0000065        None     1.8
# 4709       None  None  IC50    nM  UO_0000065        None     5.1
# 4710       None  None  IC50    nM  UO_0000065        None     0.3
# 4711       None  None  IC50    µM        None        None     2.0
#
# [4596 rows x 46 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL281957  CCN(CC)C/C=C/c1nc(O)c2c(ccc3nc(Nc4c(Cl)cccc4Cl...
# 1          CHEMBL207028                          NC(=O)c1sc(-c2ccccc2)cc1N
# 2          CHEMBL377085                       Cc1cc(C)c2c(N)c(C(N)=O)sc2n1
# 3          CHEMBL209148  COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)c...
# 4          CHEMBL386760  COc1ccc(N(C(=O)Oc2c(C)cccc2C)c2ccnc(Nc3cc(OC)c...
# ...                 ...                                                ...
# 4591      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4592      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4593      CHEMBL3707348  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
# 4594      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4595       CHEMBL460702  CCOc1ccn(-c2ccc(F)cc2)c(=O)c1C(=O)Nc1ccc(Oc2cc...
#
#      bioactivity_class standard_value
# 0               active            0.4
# 1             inactive        15100.0
# 2         intermediate         4100.0
# 3         intermediate         4100.0
# 4               active          100.0
# ...                ...            ...
# 4591            active          360.0
# 4592            active            1.8
# 4593            active            5.1
# 4594            active            0.3
# 4595            active            2.0
#
# [4596 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL281957  CCN(CC)C/C=C/c1nc(O)c2c(ccc3nc(Nc4c(Cl)cccc4Cl...
# 1          CHEMBL207028                          NC(=O)c1sc(-c2ccccc2)cc1N
# 2          CHEMBL377085                       Cc1cc(C)c2c(N)c(C(N)=O)sc2n1
# 3          CHEMBL209148  COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)c...
# 4          CHEMBL386760  COc1ccc(N(C(=O)Oc2c(C)cccc2C)c2ccnc(Nc3cc(OC)c...
# ...                 ...                                                ...
# 4707      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4708      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4709      CHEMBL3707348  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
# 4710      CHEMBL3936761  C=CC(=O)N1CCC([C@@H]2CCNc3c(C(N)=O)c(-c4ccc(Oc...
# 4711       CHEMBL460702  CCOc1ccn(-c2ccc(F)cc2)c(=O)c1C(=O)Nc1ccc(Oc2cc...
#
#      standard_value
# 0               0.4
# 1           15100.0
# 2            4100.0
# 3            4100.0
# 4             100.0
# ...             ...
# 4707          360.0
# 4708            1.8
# 4709            5.1
# 4710            0.3
# 4711            2.0
#
# [4596 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL281957  CCN(CC)C/C=C/c1nc(O)c2c(ccc3nc(Nc4c(Cl)cccc4Cl...
# 1          CHEMBL207028                          NC(=O)c1sc(-c2ccccc2)cc1N
# 2          CHEMBL377085                       Cc1cc(C)c2c(N)c(C(N)=O)sc2n1
# 3          CHEMBL209148  COc1cc(C)c(Sc2cnc(NC(=O)c3ccc(CNC(C)C(C)(C)C)c...
# 4          CHEMBL386760  COc1ccc(N(C(=O)Oc2c(C)cccc2C)c2ccnc(Nc3cc(OC)c...
# ...                 ...                                                ...
# 3902                NaN                                                NaN
# 3903                NaN                                                NaN
# 3904                NaN                                                NaN
# 4275                NaN                                                NaN
# 4276                NaN                                                NaN
#
#      standard_value             0
# 0               0.4        active
# 1           15100.0      inactive
# 2            4100.0  intermediate
# 3            4100.0  intermediate
# 4             100.0        active
# ...             ...           ...
# 3902            NaN        active
# 3903            NaN        active
# 3904            NaN  intermediate
# 4275            NaN        active
# 4276            NaN        active
#
# [4712 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 4824
# -rw-r--r-- 1 root root 4521948 Aug 13 20:51 bioactivity_data.csv
# -rw-r--r-- 1 root root  405611 Aug 13 20:53 bioactivity_preprocessed_data.csv
# drwx------ 5 root root    4096 Aug 13 20:52 gdrive
# drwxr-xr-x 1 root root    4096 Aug 10 19:19 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# ---
